# %% [markdown]
# # Analysing Effect of Lockdown on the Air Pollution in India
#
# ## Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas_visual_analysis import VisualAnalysis

# %% [markdown]
# ## Loading the dataset

# %%
pd.read_excel('Data_Analytics.xlsx', index_col=0)
# Out:
#             Alipur, Delhi - DPCC AQI  GVM Corporation, Vizag - APPCB AQI  \
# Date
# 2020-02-23                       204                                 119
# 2020-02-24                       104                                 137
# 2020-02-25                       247                                  77
# 2020-02-26                       315                                  99
# 2020-02-27                       260                                  66
# ...                              ...                                 ...
# 2020-04-19                        91                                  54
# 2020-04-20                       150                                  43
# 2020-04-21                        94                                  52
# 2020-04-22                       152                                  32
# 2020-04-23                       146                                  35
#
#             Gangapur Road, Nashik - MPCB AQI  Ballygunge, Kolkata - WBPCB AQI
# Date
# ...

# %% [markdown]
# ## Info of the dataset

# %%
df = pd.read_excel('Data_Analytics.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                61 non-null     datetime64[ns]
#  1   Alipur, Delhi - DPCC AQI            61 non-null     int64
#  2   GVM Corporation, Vizag - APPCB AQI  61 non-null     int64
#  3   Gangapur Road, Nashik - MPCB AQI    61 non-null     int64
#  4   Ballygunge, Kolkata - WBPCB AQI     61 non-null     int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 2.5 KB

# %% [markdown]
# ## Data Pre-Processing
# **Dealing with missing value**

# %%
df = pd.read_excel('Data_Analytics.xlsx')
df.isnull().sum()
# Out:
# Date                                  0
# Alipur, Delhi - DPCC AQI              0
# GVM Corporation, Vizag - APPCB AQI    0
# Gangapur Road, Nashik - MPCB AQI      0
# Ballygunge, Kolkata - WBPCB AQI       0
# dtype: int64

# %% [markdown]
# ## Describe the Statistical Analysis of the dataset

# %%
df = pd.read_excel('Data_Analytics.xlsx')
df.describe()
# Out:
#        Alipur, Delhi - DPCC AQI  GVM Corporation, Vizag - APPCB AQI  \
# count                 61.000000                           61.000000
# mean                 130.114754                           71.754098
# std                   65.304185                           25.280860
# min                   35.000000                           29.000000
# 25%                   86.000000                           54.000000
# 50%                  103.000000                           68.000000
# 75%                  178.000000                           88.000000
# max                  315.000000                          137.000000
#
#        Gangapur Road, Nashik - MPCB AQI  Ballygunge, Kolkata - WBPCB AQI
# count                         61.000000                        61.000000
# mean                          95.868852                       123.786885
# std                           36.586644                        76.521917
# ...

# %% [markdown]
# ## Central Pollution Control Board Air Quality Standards
# **Breakpoints for Air Quality Index(AQI) scale 0-500**

# %% [markdown]
# ![](analysis.png)

# %% [markdown]
# ## Loading the Date and Alipur, Delhi - DPCC AQI columns

# %%
pd.read_excel('Data_Analytics.xlsx', index_col=0, usecols=[0,1])
# Out:
#             Alipur, Delhi - DPCC AQI
# Date
# 2020-02-23                       204
# 2020-02-24                       104
# 2020-02-25                       247
# 2020-02-26                       315
# 2020-02-27                       260
# ...                              ...
# 2020-04-19                        91
# 2020-04-20                       150
# 2020-04-21                        94
# 2020-04-22                       152
# 2020-04-23                       146
#
# [61 rows x 1 columns]

# %% [markdown]
# ## Graph of Date vs Alipur, Delhi - DPCC AQI

# %%
df = pd.read_excel('Data_Analytics.xlsx')
plt.style.use('seaborn')
plt.figure(figsize=(15, 5))
plt.title('Date vs AQI', fontsize = 16)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Alipur, Delhi - DPCC AQI', fontsize = 16)
sns.lineplot(x="Date", y="Alipur, Delhi - DPCC AQI", data=df)
# Out:
# <AxesSubplot:title={'center':'Date vs AQI'}, xlabel='Date', ylabel='Alipur, Delhi - DPCC AQI'>

# %% [markdown]
# ## Loading the Date and GVM Corporation, Vizag - APPCB AQI columns

# %%
pd.read_excel('Data_Analytics.xlsx', index_col=0, usecols=[0,2])
# Out:
#             GVM Corporation, Vizag - APPCB AQI
# Date
# 2020-02-23                                 119
# 2020-02-24                                 137
# 2020-02-25                                  77
# 2020-02-26                                  99
# 2020-02-27                                  66
# ...                                        ...
# 2020-04-19                                  54
# 2020-04-20                                  43
# 2020-04-21                                  52
# 2020-04-22                                  32
# 2020-04-23                                  35
#
# [61 rows x 1 columns]

# %% [markdown]
# ## Graph of Date vs GVM Corporation, Vizag - APPCB AQI

# %%
df = pd.read_excel('Data_Analytics.xlsx')
plt.style.use('seaborn')
plt.figure(figsize=(15, 5))
plt.title('Date vs AQI', fontsize = 16)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('GVM Corporation, Vizag - APPCB AQI', fontsize = 16)
sns.lineplot(x="Date", y="GVM Corporation, Vizag - APPCB AQI", data=df)
# Out:
# <AxesSubplot:title={'center':'Date vs AQI'}, xlabel='Date', ylabel='GVM Corporation, Vizag - APPCB AQI'>

# %% [markdown]
# ## Loading the Date and Gangapur Road, Nashik - MPCB AQI columns

# %%
pd.read_excel('Data_Analytics.xlsx', index_col=0, usecols=[0,3])
# Out:
#             Gangapur Road, Nashik - MPCB AQI
# Date
# 2020-02-23                               125
# 2020-02-24                               112
# 2020-02-25                                84
# 2020-02-26                                82
# 2020-02-27                                78
# ...                                      ...
# 2020-04-19                                68
# 2020-04-20                                82
# 2020-04-21                                56
# 2020-04-22                                60
# 2020-04-23                                63
#
# [61 rows x 1 columns]

# %% [markdown]
# ## Graph of Date vs Gangapur Road, Nashik - MPCB AQI columns

# %%
df = pd.read_excel('Data_Analytics.xlsx')
plt.style.use('seaborn')
plt.figure(figsize=(15, 5))
plt.title('Date vs AQI', fontsize = 16)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Gangapur Road, Nashik - MPCB AQI', fontsize = 16)
sns.lineplot(x="Date", y="Gangapur Road, Nashik - MPCB AQI", data=df)
# Out:
# <AxesSubplot:title={'center':'Date vs AQI'}, xlabel='Date', ylabel='Gangapur Road, Nashik - MPCB AQI'>

# %% [markdown]
# ## Loading the Date and Ballygunge, Kolkata - WBPCB AQI columns

# %%
pd.read_excel('Data_Analytics.xlsx', index_col=0, usecols=[0,4])
# Out:
#             Ballygunge, Kolkata - WBPCB AQI
# Date
# 2020-02-23                              313
# 2020-02-24                              296
# 2020-02-25                              264
# 2020-02-26                              102
# 2020-02-27                               89
# ...                                     ...
# 2020-04-19                               58
# 2020-04-20                               37
# 2020-04-21                               52
# 2020-04-22                               52
# 2020-04-23                               32
#
# [61 rows x 1 columns]

# %% [markdown]
# ## Graph of Date vs Ballygunge, Kolkata - WBPCB AQI

# %%
df = pd.read_excel('Data_Analytics.xlsx')
plt.style.use('seaborn')
plt.figure(figsize=(15, 5))
plt.title('Date vs AQI', fontsize = 16)
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Ballygunge, Kolkata - WBPCB AQI', fontsize = 16)
sns.lineplot(x="Date", y="Ballygunge, Kolkata - WBPCB AQI", data=df)
# Out:
# <AxesSubplot:title={'center':'Date vs AQI'}, xlabel='Date', ylabel='Ballygunge, Kolkata - WBPCB AQI'>

# %% [markdown]
# ## Regression of Alipur, Delhi - DPCC AQI & GVM Corporation, Vizag - APPCB AQI
# ## Plotting a line of best fit of Alipur, Delhi - DPCC AQI & GVM Corporation, Vizag - APPCB AQI
#
# Plotting a line of best fit plots, the line derived from performing Ordinary Least Squares (OLS) regression on a dataset.
#
# **m = slope, b = intercept**

# %%
df = pd.read_excel('Data_Analytics.xlsx')
x = df["Alipur, Delhi - DPCC AQI"]
y = df["GVM Corporation, Vizag - APPCB AQI"]
m, b = np.polyfit(x, y, 1)
plt.style.use('seaborn')
plt.plot(x, y, 'o')
plt.plot(x, m*x + b)

# %% [markdown]
# ## Correlation with other variables

# %%
df = pd.read_excel('Data_Analytics.xlsx')
df.corr()
# Out:
#                                     Alipur, Delhi - DPCC AQI  \
# Alipur, Delhi - DPCC AQI                            1.000000
# GVM Corporation, Vizag - APPCB AQI                  0.137827
# Gangapur Road, Nashik - MPCB AQI                    0.095873
# Ballygunge, Kolkata - WBPCB AQI                     0.168219
#
#                                     GVM Corporation, Vizag - APPCB AQI  \
# Alipur, Delhi - DPCC AQI                                      0.137827
# GVM Corporation, Vizag - APPCB AQI                            1.000000
# Gangapur Road, Nashik - MPCB AQI                              0.237637
# Ballygunge, Kolkata - WBPCB AQI                               0.566102
#
#                                     Gangapur Road, Nashik - MPCB AQI  \
# Alipur, Delhi - DPCC AQI                                    0.095873
# GVM Corporation, Vizag - APPCB AQI                          0.237637
# Gangapur Road, Nashik - MPCB AQI                            1.000000
# ...
